# %% [markdown]
# <a href="https://colab.research.google.com/github/shafiqshams/data-science-and-machine-learning/blob/main/working_with_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Connecting Google colab to GitHub repo
